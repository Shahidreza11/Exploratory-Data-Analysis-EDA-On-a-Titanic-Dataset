# %% [markdown]
# # **Exploratory Data Analysis (EDA) On a Titanic Dataset**

# %% [markdown]
# Goals of the Project:
#
# 1.  To Investigate the survival rates of individual passengers.
# 2.  To Explore and validate the survival disparity between males and females
# 3.  To Develop predictive models
# 4.  To Visualize the dataset with various plot types.

# %% [markdown]
# ## Outline

# %% [markdown]
# ## Materials

# %% [markdown]
# The data that we are going to use for this is a subset of an open source Titanic dataset from kaggle website:
#
# https://www.kaggle.com/datasets/yasserh/titanic-dataset
#
# In this project, I will try to give answers to a set of questions that may be relevant when analyzing Titanic data:

# %% [markdown]
# ## Dataset exploration

# %% [markdown]
# ### Column Types
#
# - **Numerical** - Age,Fare,PassengerId
# - **Categorical** - Survived, Pclass, Sex, SibSp, Parch,Embarked
# - **Mixed** - Name, Ticket, Cabin
#
# Identifying the types of columns as numerical, categorical, or mixed is crucial as it enhances our ability to perform more effective analyses.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
train=pd.read_csv(r"C:\Users\shahi\OneDrive\Desktop\train.csv")
test=pd.read_csv(r"C:\Users\shahi\OneDrive\Desktop\test.csv")

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train['PassengerId'].shape[0]
# Out:
# 891

# %% [markdown]
# ### Univariate Analysis
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# ### Age

# %%
train['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
plt.hist(train['Age'],bins=20)
plt.show()

# %%
sns.kdeplot(data=train,x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
plt.hist(train['Age'],bins=20)
plt.show()

# %%
train['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
train[train['Age']>65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
((train['Age'].isnull().sum())/train['Age'].shape[0])*100
# Out:
# 19.865319865319865

# %% [markdown]
# **conclusions**
#
# - Age is normally(almost) distributed
# - 20% of the values are missing
# - There are some outliers

# %% [markdown]
# ## Fare

# %%
train['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
plt.hist(train['Fare'])
plt.show()

# %%
sns.kdeplot(train['Fare'])
plt.show()

# %%
train['Fare'].skew()
# Out:
# 4.787316519674893

# %%
plt.boxplot(train['Fare'])
plt.show()

# %%
train[train['Fare']>250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %% [markdown]
# **Conclusion**
#
# - The data is highly(positively) skewed
# - Fare column actually contains the group fare and not the individual fare(This migth be and issue)
# - We need to create a new col called individual fare

# %% [markdown]
# ## Univariate Analysis on Categorical columns
# Computing the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Survived**

# %%
train['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
train['Survived'].value_counts().plot(kind='bar')
plt.show()

# %%
plt.pie(s,autopct='%0.1f%%')
plt.show()

# %%
train['Survived'].isnull().sum()
# Out:
# 0

# %% [markdown]
# * conclusion
# * The accident was very deadly because more than 50% could not survived the accident.
# * Out of all passengers 61.6% people have died and only 38.4 percent people have been survived

# %% [markdown]
# ## Pclass

# %%
train['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
train['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
train['Pclass'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Outcome:**
# - The majority of passengers, 491 in total, traveled in third class, whereas fewer passengers opted for second class and the highest number traveled in first class.

# %% [markdown]
# ## Gender

# %%
train['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
train['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
train['Sex'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
train['Sex'].isna().sum()
# Out:
# 0

# %% [markdown]
# **conclusion**
#
# - 64.8% females are travelling in the ship where as males are travelling only 35.2% people.

# %% [markdown]
# ## SibSp

# %%
train['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
train['SibSp'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SibSp'>

# %%
train['SibSp'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
train['SibSp'].isna().sum()
# Out:
# 0

# %% [markdown]
# **Conclusion**
# - Passengers traveling with siblings, spouses, or both are referred to as having "sibsp" in the dataset.
# - There are 68.2% individuals are travelling in the ship.
# - 23.5% people are travelling pairs.
# - Only 0.6% people are travelling with 5 members.

# %% [markdown]
# ## Parch

# %%
### parents travelling with their childs
train['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
train['Parch'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Parch'>

# %%
plt.figure(figsize=(15,7))
train['Parch'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Conclusion**
# - Parents traveling with their children are referred to as having "parch" in the dataset.
# - parch (parent child ) and sibsp (siblings , husband and wife) can be merged to form a new col called family size
#   create a new column called is_alone

# %% [markdown]
# **Embarked**
#
# -The boarding points or ports of embarkation for the passengers.

# %%
train['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
train['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
train['Embarked'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
train['Embarked'].isnull().sum()
# Out:
# 2

# %%
train[train['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# **Conclusion**
#
# -74.2% people are embarked from the S.
#
# -8.7% people are embarked from the Q

# %% [markdown]
# ### Steps of doing Bivariate Analysis

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
# 2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
# 3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps

# %% [markdown]
# **Survived with Pclass**

# %%
pd.crosstab(train['Survived'],train['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
pd.crosstab(train['Survived'],train['Pclass'],normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
sns.heatmap(pd.crosstab(train['Survived'],train['Pclass'],normalize='columns')*100)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# **Conclusion**
#
# - In Pclass 1 only 37% of passengers died and 62% survived, whereas Pclass 3 was the most dangerous class with 75% of passengers have died.

# %% [markdown]
# **Survived with Sex**

# %%
pd.crosstab(train['Survived'],train['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.crosstab(train['Survived'],train['Sex'],normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
sns.heatmap(pd.crosstab(train['Survived'],train['Sex'],normalize='columns'))
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# **Conclusion**
#
# - More females, approximately 74%, survived the accident, while approximately 81% of males perished.

# %% [markdown]
# **survived with embarked**

# %%
pd.crosstab(train['Survived'],train['Embarked'])
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
pd.crosstab(train['Survived'],train['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %% [markdown]
# **Question:** Why did passengers who boarded/embarked from port 'C' have a higher survival rate (55%) compared to other ports?
#
# **Assumption-1:** Perhaps passengers embarking from port 'C' had a higher proportion of females, given females had a higher survival rate (74%) compared to males as shown in previous analysis.
#
# **Assumption-2:** It could be that passengers embarking from port 'C' were predominantly traveling in Pclass 1, where the survival rate was 62%.

# %% [markdown]
# **Assumption-1**

# %%
pd.crosstab(train['Sex'],train['Embarked'])
# Out:
# Embarked   C   Q    S
# Sex
# female    73  36  203
# male      95  41  441

# %%
pd.crosstab(train['Sex'],train['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %% [markdown]
# **Conclusion**
# - Assumption 1 is incorrect because females who embarked from port 'C' are not more than males; in fact, there are more females who embarked from port 'Q'.

# %% [markdown]
# **Assumption-2**

# %%
pd.crosstab(train['Pclass'],train['Embarked'])
# Out:
# Embarked   C   Q    S
# Pclass
# 1         85   2  127
# 2         17   3  164
# 3         66  72  353

# %%
pd.crosstab(train['Pclass'],train['Embarked'],normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %% [markdown]
# **Conclusion**
# - The Assumption 2 is correct. people who embarked from C are predominantly travelling in Pclass 1.

# %% [markdown]
# ## Numerical with Categorical
# **Survived with Age**

# %%
sns.kdeplot(train[train['Survived']==1]['Age'],label='SURVIVED')
sns.kdeplot(train[train['Survived']==0]['Age'],label='DIED')
plt.legend()
plt.show()

# %%
train[train['Pclass']==1]['Age'].mean()
# Out:
# 38.233440860215055

# %% [markdown]
# **Conclusion**
# - Children aged 0 to 5 show a higher survival rate (blue curve) compared to the death rate (orange curve).
# - From ages 10 to 40, the death rate (orange curve) surpasses the survival rate, indicating higher mortality among this age group.
# - Beyond age 40, the survival rate (blue curve) begins to dominate again until around age 45, possibly influenced by passengers in Pclass 1, where the average age is 37.

# %% [markdown]
# **Feature Engineering:**
# - Focus on the fare column, ideally showing individual fares instead of grouped fares.
# - Note that the train data doesn't include all passengers; the remaining are in the test dataset.
# - Concatenating datasets could provide better results for analysis and modeling.

# %%
concated= pd.concat([train,test])
concated
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
concated['Ticket'].value_counts()
# Out:
# Ticket
# CA. 2343        11
# CA 2144          8
# 1601             8
# PC 17608         7
# S.O.C. 14879     7
#                 ..
# 113792           1
# 36209            1
# 323592           1
# 315089           1
# 359309           1
# Name: count, Length: 929, dtype: int64

# %%
concated[concated['Ticket']=='CA 2144']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60       0.0       3       Goodwin, Master. William Frederick
# 71            72       0.0       3               Goodwin, Miss. Lillian Amy
# 386          387       0.0       3          Goodwin, Master. Sidney Leonard
# 480          481       0.0       3           Goodwin, Master. Harold Victor
# 678          679       0.0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684       0.0       3              Goodwin, Mr. Charles Edward
# 139         1031       NaN       3           Goodwin, Mr. Charles Frederick
# 140         1032       NaN       3              Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S
# 386    male   1.0      5      2  CA 2144  46.9   NaN        S
# ...

# %% [markdown]
# **Divide the fare individually and creating new column as individualfare**

# %%
concated['indvidualfare']=concated['Fare']/(concated['SibSp']+concated['Parch']+1)

# %%
concated
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
concated[concated['indvidualfare']>400]
# Out:
#      PassengerId  Survived  Pclass                    Name     Sex   Age  \
# 258          259       1.0       1        Ward, Miss. Anna  female  35.0
# 737          738       1.0       1  Lesurer, Mr. Gustave J    male  35.0
#
#      SibSp  Parch    Ticket      Fare Cabin Embarked  indvidualfare
# 258      0      0  PC 17755  512.3292   NaN        C       512.3292
# 737      0      0  PC 17755  512.3292  B101        C       512.3292

# %%
sns.boxplot(concated['indvidualfare'])
# Out:
# <Axes: ylabel='indvidualfare'>

# %% [markdown]
# **Conclusion**
#
# - Though fare are distributed indvidually there are some outliers because passengerid 259 and 738 has really bought ticket at the price of $512**

# %%
concated[['indvidualfare','Fare']].describe()
# Out:
#        indvidualfare         Fare
# count    1308.000000  1308.000000
# mean       20.518215    33.295479
# std        35.774337    51.758668
# min         0.000000     0.000000
# 25%         7.452767     7.895800
# 50%         8.512483    14.454200
# 75%        24.237500    31.275000
# max       512.329200   512.329200

# %% [markdown]
# # Sibsp and parch
# - Creating the total family column by adding sibspa and parch columns

# %%
concated['Family_size']=concated['SibSp']+concated['Parch']+1

# %%
concated
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Creating Family Type:
#
# **Family type is defined as:**
#
# - 1: Alone
# - 2 to 4: Small family
# - 3: Large family

# %%
def familysize(num):
    if num==1:
        return 'alone'
    elif num>1 and num<5:
        return 'small'
    else:
        return 'large'
concated['family_type']=concated['Family_size'].apply(familysize)

# %%
concated
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(concated['Survived'],concated['family_type'])
# Out:
# family_type  alone  large  small
# Survived
# 0.0            374     52    123
# 1.0            163     10    169

# %%
pd.crosstab(concated['Survived'],concated['family_type'],normalize='columns')*100
# Out:
# family_type      alone      large      small
# Survived
# 0.0          69.646182  83.870968  42.123288
# 1.0          30.353818  16.129032  57.876712

# %% [markdown]
# **Conclusion**
# - Traveling alone on the Titanic results in a 69% chance of dying.
# - Traveling in a large family increases the chance of dying to 83%.
# - Traveling in a small family on the Titanic offers a higher chance (57%) of survival.

# %% [markdown]
# **Extracting the Surnames from the Name column and insert into new column**

# %%
concated['Surname']=concated['Name'].str.split(',').str.get(0)

# %%
concated
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Multivariate Analysis**

# %%
concated.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'indvidualfare',
#        'Family_size', 'family_type', 'Surname'],
#       dtype='object')

# %% [markdown]
# The `corr()` function in pandas computes pairwise correlation of Numerical columns in a DataFrame. It shows how strongly pairs of columns are related: a value closer to 1 indicates a strong positive correlation, while closer to -1 indicates a strong negative correlation.

# %%
fulldata=concated[['PassengerId', 'Survived', 'Pclass',  'Age', 'SibSp',
       'Parch', 'Fare', 'indvidualfare',
       'Family_size']]

# %%
fulldata.corr()
# Out:
#                PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId       1.000000 -0.005007 -0.038354  0.028814 -0.055224  0.008942
# Survived         -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass           -0.038354 -0.338481  1.000000 -0.408106  0.060832  0.018322
# Age               0.028814 -0.077221 -0.408106  1.000000 -0.243699 -0.150917
# SibSp            -0.055224 -0.035322  0.060832 -0.243699  1.000000  0.373587
# Parch             0.008942  0.081629  0.018322 -0.150917  0.373587  1.000000
# Fare              0.031428  0.257307 -0.558629  0.178740  0.160238  0.221539
# indvidualfare     0.035365  0.221600 -0.504270  0.193545 -0.089807 -0.065498
# Family_size      -0.031437  0.016639  0.050027 -0.240229  0.861952  0.792296
#
#                    Fare  indvidualfare  Family_size
# PassengerId    0.031428       0.035365    -0.031437
# Survived       0.257307       0.221600     0.016639
# ...

# %%
fulldata.corr()['Survived']
# Out:
# PassengerId     -0.005007
# Survived         1.000000
# Pclass          -0.338481
# Age             -0.077221
# SibSp           -0.035322
# Parch            0.081629
# Fare             0.257307
# indvidualfare    0.221600
# Family_size      0.016639
# Name: Survived, dtype: float64

# %% [markdown]
# - Survived is strongly correlated with individual fare, suggesting that higher fares may correlate with higher survival rates.
# - Age shows a negative correlation with survival, indicating that older passengers were less likely to survive the Titanic disaster.

# %%
sns.heatmap(fulldata.corr())
# Out:
# <Axes: >

# %% [markdown]
# As bright as colour goes up there is a postitve relationship between two columns.

# %% [markdown]
# A pair plot is a grid of scatterplots that shows the relationships between pairs of variables in a dataset. It plots every variable against every other variable, helping to visualize correlations and distributions across the dataset at once.

# %%
sns.pairplot(train)

# %% [markdown]
# ## Conclusion
# - Based on a comprehensive analysis of the Titanic dataset, several key insights have emerged.
# - Passengers in the lowest class (Pclass 3) experienced the highest mortality rate, highlighting socioeconomic disparities in survival.
# - Gender proved pivotal, with females demonstrating a significantly higher survival rate compared to males.
# - Age also played a critical role, with children and younger adults more likely to survive than older passengers.
# - Family dynamics further influenced survival outcomes, as individuals traveling alone or in smaller families had better chances of survival compared to those in larger families.
# - These findings underscore the multifaceted factors influencing survival aboard the Titanic, from class distinctions and gender biases to age-related vulnerabilities and family size dynamics.
